# %%
import pandas as pd

# %%
df = pd.read_csv("missing_data.csv")
df.isnull().sum() #to check how many missing values are there in evry column
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
# now filling missing vlaues to the mean of their columns - we use .fillna method
# BMI has 11 mssing NaN places so lets create a new column for that
df['BMI_fillNA'] = df['BMI'].fillna(df['BMI'].mean())

df
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class  BMI_fillNA
# 0                0.627   50      1        33.6
# ...

# %%
# renaming the column names
df =  df.rename(columns={'BMI': 'BMI_Index'})

# %%
# changing datatypees od columns

# df['BMI_Index'] = df['BMI_Index'].astype(int) # this might couse error as that column may have missing values

# df['BMI_Index'] = df['BMI_Index'].fillna(df['BMI_Index'].mean()).astype(int) 
df
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin  BMI_Index  \
# 0           6    148.0          72.0       35.0            NaN         33
# 1           1     85.0          66.0       29.0            NaN         26
# 2           8    183.0          64.0        NaN            NaN         23
# 3           1     89.0          66.0       23.0           94.0         28
# 4           0    137.0          40.0       35.0          168.0         43
# ..        ...      ...           ...        ...            ...        ...
# 763        10    101.0          76.0       48.0          180.0         32
# 764         2    122.0          70.0       27.0            NaN         36
# 765         5    121.0          72.0       23.0          112.0         26
# 766         1    126.0          60.0        NaN            NaN         30
# 767         1     93.0          70.0       31.0            NaN         30
#
#      Diabetes_Pedigree  Age  Class  BMI_fillNA
# ...

# %%
# calculating grouped mean
grouped_mean = df.groupby('BMI_Index')['Glucose'].mean()
grouped_mean

# %%
# going to merge dataframes,  so lets create another one
# df1 = df.rename(columns={'Skin': 'Skin_Fold'})
# df1.isnull().sum()
df1 = df.copy()
df1['Skin_Fold'] = df['Skin_Fold'].fillna(df['Skin_Fold'].mean()).astype(int)
df1
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin  BMI_Index  \
# 0           6    148.0          72.0         35            NaN         33
# 1           1     85.0          66.0         29            NaN         26
# 2           8    183.0          64.0         29            NaN         23
# 3           1     89.0          66.0         23           94.0         28
# 4           0    137.0          40.0         35          168.0         43
# ..        ...      ...           ...        ...            ...        ...
# 763        10    101.0          76.0         48          180.0         32
# 764         2    122.0          70.0         27            NaN         36
# 765         5    121.0          72.0         23          112.0         26
# 766         1    126.0          60.0         29            NaN         30
# 767         1     93.0          70.0         31            NaN         30
#
#      Diabetes_Pedigree  Age  Class  BMI_fillNA
# ...

# %%
# lets merge BMI_Index and BMI_fillNA
pd.merge(df, df1, on='Skin_Fold', how='inner')
# Out:
#        Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold  Serum_Insulin_x  \
# 0               6      148.0            72.0       35.0              NaN
# 1               6      148.0            72.0       35.0              NaN
# 2               6      148.0            72.0       35.0              NaN
# 3               6      148.0            72.0       35.0              NaN
# 4               6      148.0            72.0       35.0              NaN
# ...           ...        ...             ...        ...              ...
# 12555           1       93.0            70.0       31.0              NaN
# 12556           1       93.0            70.0       31.0              NaN
# 12557           1       93.0            70.0       31.0              NaN
# 12558           1       93.0            70.0       31.0              NaN
# 12559           1       93.0            70.0       31.0              NaN
#
#        BMI_Index_x  Diabetes_Pedigree_x  Age_x  Class_x  BMI_fillNA_x  \
# ...
